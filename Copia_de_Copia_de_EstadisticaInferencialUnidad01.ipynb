# %% [markdown]
# <a href="https://colab.research.google.com/github/Dalai302/EstadisticaVerano/blob/main/Copia_de_Copia_de_EstadisticaInferencialUnidad01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({'examenes_cortos':
[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
"promedios_finales":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]})
#df.head() #head solo muestra loos primeros 5 elementos
x=df["examenes_cortos"]
y=df["promedios_finales"]
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5),dpi=100)
plt.scatter(x,y,label="promedio_final",color="pink") #aparece grafica con especificaciones
plt.title("Grafico de dispersion")
plt.xlabel("examenes cortos")
plt.ylabel("Promedio final")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False) #Elimina las rayas de arriba y abajo
sxx=((x-x.mean())**2).sum()
print(sxx)
sxy=((x-x.mean())*(y-y.mean())).sum()
print(sxy)
syy=((y-y.mean())**2).sum()
print(syy)
r=sxy/((sxx*syy)**0.5)
print(r)
r2=r**2
print(r2) #74.45% de la inf necesaria dice cuanta inf aporta x
b1=sxy/sxx
print(b1)
b0=y.mean()-b1*x.mean()
print(b0)
yc=b0+b1*x #recta de regresion ajustada
plt.plot(x,yc,color="blue",label="recta de regresion ajustada")
plt.legend()
plt.show()
n=len(x)
sse=((y-yc)**2).sum()
print(sse)
se_b1=((sse/(n-2))/sxx)**0.5
print(se_b1)
t=(b1/se_b1)
print(t)
nivel_significancia= 0.05
from scipy.stats import t
T= t.ppf(1-nivel_significancia/2,df=n-2)
print(f"{b1-T*se_b1}<b1<{b1+T*se_b1}")
residuales=y-yc
plt.scatter(x,residuales,color="purple",label="residuales")
plt.legend()
plt.axhline(y=0,color="black")
plt.scatter(x,residuales,color="purple",label="residuales")
#modelo cuadrado es mejor
from scipy.stats import shapiro #esta prueba me dice si hay normalidad en la distribucion
estadistico_shapiro,valor_p_sh=shapiro=shapiro(residuales)
print(f"estadistico_shapiro={estadistico_shapiro}")
print(f"valor_p_sh={valor_p_sh}") #nos quedamos con h0 ya que es mayor que el nivel de significancia
print("x=70,y=",b0+b1*70)
print("x=75,y=",b0+b1*75)
print("x=84,y=",b0+b1*84)
# Out:
# 3718.3999999999996
# 2391.6
# 2057.733333333333
# 0.8646014213752985
# 0.7475356178441864
# 0.6431798623063684
# 24.52682157200229
# 519.5043746414227
# 0.10366803702650947
# 6.2042253403708
# 0.4192186844374576<b1<0.8671410401752792
# estadistico_shapiro=0.9731638066576076
# valor_p_sh=0.901827735700704
# x=70,y= 69.54941193344808
# x=75,y= 72.76531124497993
# x=84,y= 78.55393000573724

# %%
import pandas as pd
df=pd.DataFrame({'examenes_cortos':
[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
"promedios_finales":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]})
x=df["examenes_cortos"]
y=df["promedios_finales"]
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5),dpi=100)
plt.scatter(x,y,label="promedio_final",color="pink") #aparece grafica con especificaciones
plt.title("Grafico de dispersion")
plt.xlabel("examenes cortos")
plt.ylabel("Promedio final")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
from scipy.stats import pearsonr
r,_=pearsonr(x,y)
print("r=",r)
from sklearn.metrics import r2_score
r2=r2_score(y,yc)
print("coeficiente de determinacion=",r2)
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
yc= modelo.predict(x_constante)
print(yc)
plt.plot(x,yc,color="yellow",label="recta de regresion ajustada")
plt.legend()
print("intervalos de confianza",modelo.conf_int(0.05))
residuales=y-yc
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5),dpi=70)
plt.scatter(x,residuales,label="promedio",color="blue")
plt.axhline(y=0,color="red",linestyle="--")
plt.title("Grafico de Calificaciones")
plt.xlabel("Examenes cortos")
plt.ylabel("Promedio final")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
print(residuales)
from scipy.stats import shapiro #esta prueba me dice si hay normalidad en la distribucion
estadistico_shapiro,valor_p_sh=shapiro=shapiro(residuales)
print(f"estadistico_shapiro={estadistico_shapiro}")
from statsmodels.stats.api import het_breuschpagan
_,valor_p_bp,_,_=het_breuschpagan(residuales,x_constante)
print(f"valor_p_bp={valor_p_bp}")
from statsmodels.formula.api import ols
modelo_anova=ols("promedios_finales ~ examenes_cortos",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_anova)
print(tabla_anova)
# Out:
# r= 0.8646014213752982
# coeficiente de determinacion= 0.7475356178441863
# 0     62.474433
# 1     83.699369
# 2     70.835772
# 3     82.413009
# 4     85.628908
# 5     80.483470
# 6     81.769829
# 7     74.051671
# 8     73.408491
# 9     66.333513
# 10    86.915268
# 11    51.540376
# 12    84.985729
# 13    64.403973
# 14    83.056189
# dtype: float64
# intervalos de confianza                         0          1
# const            6.441997  42.611646
# examenes_cortos  0.419219   0.867141
# 0      1.525567
# 1      0.300631
# 2      6.164228
# 3     -2.413009
# 4     -8.628908
# 5      0.516530
# 6     -1.769829
# 7      9.948329
# 8      6.591509
# 9      2.666487
# 10    -3.915268
# 11   -11.540376
# 12    -6.985729
# 13     0.596027
# 14     6.943811
# dtype: float64
# estadistico_shapiro=0.9731638066576076
# valor_p_bp=0.2288872132755837
#                    df       sum_sq      mean_sq          F    PR(>F)
# examenes_cortos   1.0  1538.228959  1538.228959  38.492412  0.000032
# Residual         13.0   519.504375    39.961875        NaN       NaN

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
#Establesca una variable dependiente (Y) y una variable independiente (X).
import pandas as pd
df=pd.DataFrame({"salario":[11, 10, 8, 5, 9, 7, 3, 11, 8, 7, 2, 9, 8, 3],
                 "ausencias":[18, 17, 29, 36, 11, 28, 35, 14, 20, 32, 39, 16, 31, 40]})
print(df)
x=df["salario"]
y=df["ausencias"]
#Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5),dpi=100)
plt.scatter(x,y,label="salario",color="pink") #aparece grafica con especificaciones
plt.title("Grafico de dispersion")
plt.xlabel("ausencias")
plt.ylabel("salario")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
#¿Los datos soportan la suposición de linealidad?si

#Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r,_=pearsonr(x,y)
print("coeficiente de correlacion:{r=:0.4f}\n")

#6
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
yc= modelo.predict(x_constante)
print(yc)
plt.plot(x,yc,color="black",label="recta de regresion ajustada")
plt.legend()

#5 #Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score
r2=r2_score(y,yc)
print(f"coeficiente de determinacion:{r2=:0.4f}\n")
#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada (b1)
print("coeficiente de determinacion=",r2)
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
yc= modelo.predict(x_constante)
print(yc)
plt.legend()
print("intervalos de confianza",modelo.conf_int(0.05))
residuales=y-yc
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5),dpi=70)
plt.scatter(x,residuales,label="ausencias",color="pink")
plt.axhline(y=0,color="black",linestyle="--")
plt.title("Grafico de salario y ausencias")
plt.xlabel("ausencias")
plt.ylabel("salario")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
print(residuales)
from scipy.stats import shapiro #esta prueba me dice si hay normalidad en la distribucion
_,valor_p_sh=shapiro=shapiro(residuales)
print(f"valor_p_shapiro={valor_p_sh}")
from statsmodels.stats.api import het_breuschpagan
_,valor_p_bp,_,_=het_breuschpagan(residuales,x_constante)
print(f"valor_p_bp={valor_p_bp}")
#11 Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
print(f"para x =5, y = {modelo.predict([1, 5])}")
print(f"para x =8, y = {modelo.predict([1, 8])}")
print(f"para x =15, y = {modelo.predict([1, 15])}\n")
from statsmodels.formula.api import ols
modelo_anova=ols("ausencias ~ salario",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_anova)
print(tabla_anova)
# Out:
#     salario  ausencias
# 0        11         18
# 1        10         17
# 2         8         29
# 3         5         36
# 4         9         11
# 5         7         28
# 6         3         35
# 7        11         14
# 8         8         20
# 9         7         32
# 10        2         39
# 11        9         16
# 12        8         31
# 13        3         40
# coeficiente de correlacion:{r=:0.4f}
#
# 0     14.942149
# 1     17.900826
# 2     23.818182
# 3     32.694215
# 4     20.859504
# 5     26.776860
# 6     38.611570
# 7     14.942149
# 8     23.818182
# 9     26.776860
# 10    41.570248
# 11    20.859504
# 12    23.818182
# 13    38.611570
# dtype: float64
# coeficiente de determinacion:r2=0.7746
#
# coeficiente de determinacion= 0.7746222969404379
# 0     14.942149
# 1     17.900826
# 2     23.818182
# 3     32.694215
# 4     20.859504
# 5     26.776860
# 6     38.611570
# 7     14.942149
# 8     23.818182
# 9     26.776860
# 10    41.570248
# 11    20.859504
# 12    23.818182
# 13    38.611570
# dtype: float64
# intervalos de confianza                  0          1
# const    39.707750  55.267457
# salario  -3.962455  -1.954900
# 0     3.057851
# 1    -0.900826
# 2     5.181818
# 3     3.305785
# 4    -9.859504
# 5     1.223140
# 6    -3.611570
# 7    -0.942149
# 8    -3.818182
# 9     5.223140
# 10   -2.570248
# 11   -4.859504
# 12    7.181818
# 13    1.388430
# dtype: float64
# valor_p_shapiro=0.8932566424098969
# valor_p_bp=0.4504810380003609
# para x =5, y = [32.69421488]
# para x =8, y = [23.81818182]
# para x =15, y = [3.10743802]
#
#             df      sum_sq     mean_sq          F    PR(>F)
# salario    1.0  983.548996  983.548996  41.243954  0.000033
# Residual  12.0  286.165289   23.847107        NaN       NaN

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
#Establesca una variable dependiente (Y) y una variable independiente (X).
import pandas as pd
df=pd.DataFrame({"gastos_generales" : [191, 170, 272, 155, 280, 173, 234, 116, 153, 178],
                 "unidades" : [40, 42, 53, 35, 56, 39, 48, 30, 37, 40]})
print(df)
x=df["unidades"]
y=df["gastos_generales"]

#Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5),dpi=100)
plt.scatter(x,y,label="gastos generales",color="pink") #aparece grafica con especificaciones
plt.title("Grafico de dispersion")
plt.xlabel("gastos generales")
plt.ylabel("unidades")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
#¿Los datos soportan la suposición de linealidad?si

#Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r,_=pearsonr(x,y)
print(f"coeficiente de correlacion:{r=:0.4f}\n") #.4=mostrara 4 decimales

#6
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
yc= modelo.predict(x_constante)
print(yc)
plt.plot(x,yc,color="yellow",label="recta de regresion ajustada")
plt.legend()

#5 #Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score
r2=r2_score(y,yc)
print(f"coeficiente de determinacion:{r2=:0.4f}\n")

#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada (b1)
print("coeficiente de determinacion=",r2)
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
yc= modelo.predict(x_constante)
print(yc)
plt.legend()
print(f"intervalos de confianza",modelo.conf_int(0.05))
#8
residuales=y-yc
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5),dpi=70)
plt.scatter(x,residuales,label="unidades",color="blue")
plt.axhline(y=0,color="red",linestyle="--")
plt.title("gastos generales y unidades")
plt.xlabel("unidades")
plt.ylabel("gastos generales")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
print(residuales)
from scipy.stats import shapiro #esta prueba me dice si hay normalidad en la distribucion
_,valor_p_sh=shapiro(residuales)
print(f"estadistico_shapiro={valor_p_sh}")
from statsmodels.stats.api import het_breuschpagan
_,valor_p_bp,_,_=het_breuschpagan(residuales,x_constante)
print(f"valor_p_bp={valor_p_bp}")
#11
print(f"estadistico_shapiro={valor_p_sh}")
print(f"para x =100, y = {modelo.predict([1, 100])}")
print(f"para x =150, y = {modelo.predict([1, 150])}\n")
from statsmodels.formula.api import ols
modelo_anova=ols("gastos_generales ~ unidades",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_anova)
print(tabla_anova)
#RESUMEN
#TEST DE SHAPR
#Ho:Normal H1: No normal &:0.05 valor-p:0.2205
 #(aprovamos la hipotesis nula ya que valor p es mas grande que &)
#TEST BP
#Ho: homoscedasticidad H1:heteroscedasticidad &:0.05 valor p:0.9858
#(aprovamos la hipotesis nula ya que valor p es mas grande que &)
#TEST ANOVA
#Ho: b1=o h1:b1 no es igual 0 &:0.05 valor p:0.0000003167
#se rechaza ya que no es igual el valor p a 0 y el valor p es menor que &
#Conclusion: soporta la suposicion de linealidad, normalidad en los reciduales,
#homoscedasticidad, relacion fuerte entre X y Y, el modelo es confiable
# Out:
#    gastos_generales  unidades
# 0               191        40
# 1               170        42
# 2               272        53
# 3               155        35
# 4               280        56
# 5               173        39
# 6               234        48
# 7               116        30
# 8               153        37
# 9               178        40
# coeficiente de correlacion:r=0.9835
#
# 0    179.217007
# 1    192.200000
# 2    263.606463
# 3    146.759524
# 4    283.080952
# 5    172.725510
# 6    231.148980
# 7    114.302041
# 8    159.742517
# 9    179.217007
# dtype: float64
# coeficiente de determinacion:r2=0.9673
#
# coeficiente de determinacion= 0.967302835655101
# 0    179.217007
# 1    192.200000
# 2    263.606463
# 3    146.759524
# 4    283.080952
# 5    172.725510
# 6    231.148980
# 7    114.302041
# 8    159.742517
# 9    179.217007
# dtype: float64
# intervalos de confianza                    0          1
# const    -121.986373 -38.899341
# unidades    5.518450   7.464543
# 0    11.782993
# 1   -22.200000
# 2     8.393537
# 3     8.240476
# 4    -3.080952
# 5     0.274490
# 6     2.851020
# 7     1.697959
# 8    -6.742517
# 9    -1.217007
# dtype: float64
# estadistico_shapiro=0.22045077017698533
# valor_p_bp=0.9858309862929234
# estadistico_shapiro=0.22045077017698533
# para x =100, y = [568.70680272]
# para x =150, y = [893.28163265]
#
#            df        sum_sq       mean_sq           F        PR(>F)
# unidades  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual  8.0    837.557483    104.694685         NaN           NaN

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
#Establesca una variable dependiente (Y) y una variable independiente (X).
import pandas as pd
df=pd.DataFrame({"construccion_de_casas" : [2.0, 2.5, 3.2, 3.6, 3.7, 4.0, 4.2, 4.6, 4.8, 5.0],
                 "ventas_linea_blanca" : [5.0, 5.5, 6.0, 7.0, 7.2, 7.7, 8.4, 9.0, 9.7, 10.0]})
print(df)
x=df["construccion_de_casas"]
y=df["ventas_linea_blanca"]

#Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5),dpi=100)
plt.scatter(x,y,label="gastos generales",color="pink") #aparece grafica con especificaciones
plt.title("Grafico de dispersion")
plt.xlabel("construccion_de_casas")
plt.ylabel("ventas_linea_blanca")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
#¿Los datos soportan la suposición de linealidad?si

#Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r,_=pearsonr(x,y)
print(f"coeficiente de correlacion:{r=:0.4f}\n") #.4=mostrara 4 decimales

#6
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
yc= modelo.predict(x_constante)
print(yc)
plt.plot(x,yc,color="yellow",label="recta de regresion ajustada")
plt.legend()

#5 #Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score
r2=r2_score(y,yc)
print(f"coeficiente de determinacion:{r2=:0.4f}\n")

#7 Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada (b1)
print("coeficiente de determinacion=",r2)
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
yc= modelo.predict(x_constante)
print(yc)
plt.legend()
print(f"intervalos de confianza",modelo.conf_int(0.05))
#8
residuales=y-yc
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5),dpi=70)
plt.scatter(x,residuales,label="construccion_de_casas",color="blue")
plt.axhline(y=0,color="red",linestyle="--")
plt.title("construccion_de_casas y ventas_linea_blanca")
plt.xlabel("construccion_de_casas")
plt.ylabel("ventas_linea_blanca")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)
print(residuales)
from scipy.stats import shapiro #esta prueba me dice si hay normalidad en la distribucion
_,valor_p_sh=shapiro(residuales)
print(f"estadistico_shapiro={valor_p_sh}")
from statsmodels.stats.api import het_breuschpagan
_,valor_p_bp,_,_=het_breuschpagan(residuales,x_constante)
print(f"valor_p_bp={valor_p_bp}")
#11
print(f"estadistico_shapiro={valor_p_sh}")
print(f"para x =2.0, y = {modelo.predict([1, 2.0])}")
print(f"para x =2.5, y = {modelo.predict([1, 2.5])}\n")
from statsmodels.formula.api import ols
modelo_anova=ols("construccion_de_casas ~ ventas_linea_blanca",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_anova)
print(tabla_anova)

#conclusiones
#no soporta la suposicion lineal porque se puede predecir
#normalidad en los residuales puntps mas cerca que lejos
#relacion fuerte entre x y y
#homoscedasticidad breush pagan
#confiable solo para interpolacion
# Out:
#    construccion_de_casas  ventas_linea_blanca
# 0                    2.0                  5.0
# 1                    2.5                  5.5
# 2                    3.2                  6.0
# 3                    3.6                  7.0
# 4                    3.7                  7.2
# 5                    4.0                  7.7
# 6                    4.2                  8.4
# 7                    4.6                  9.0
# 8                    4.8                  9.7
# 9                    5.0                 10.0
# coeficiente de correlacion:r=0.9808
#
# 0    4.491887
# 1    5.360669
# 2    6.576964
# 3    7.271990
# 4    7.445746
# 5    7.967015
# 6    8.314528
# 7    9.009554
# 8    9.357066
# 9    9.704579
# dtype: float64
# coeficiente de determinacion:r2=0.9619
#
# coeficiente de determinacion= 0.9619174471452718
# 0    4.491887
# 1    5.360669
# 2    6.576964
# 3    7.271990
# 4    7.445746
# 5    7.967015
# 6    8.314528
# 7    9.009554
# 8    9.357066
# 9    9.704579
# dtype: float64
# intervalos de confianza                               0         1
# const                 -0.074848  2.108368
# construccion_de_casas  1.455693  2.019435
# 0    0.508113
# 1    0.139331
# 2   -0.576964
# 3   -0.271990
# 4   -0.245746
# 5   -0.267015
# 6    0.085472
# 7   -0.009554
# 8    0.342934
# 9    0.295421
# dtype: float64
# estadistico_shapiro=0.8463507249054649
# valor_p_bp=0.15813934528309412
# estadistico_shapiro=0.8463507249054649
# para x =2.0, y = [4.49188749]
# para x =2.5, y = [5.36066946]
#
#                       df    sum_sq   mean_sq           F        PR(>F)
# ventas_linea_blanca  1.0  8.276338  8.276338  202.069951  5.841003e-07
# Residual             8.0  0.327662  0.040958         NaN           NaN

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.
